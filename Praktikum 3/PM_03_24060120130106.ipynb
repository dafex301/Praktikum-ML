# %% [markdown]
# # Elbow Method
# ---
# ### Fahrel Gibran Alghany - 24060120130106 - C2
#
# ---
#
# 08/11/2022
#
# ---

# %% [markdown]
# ## Mengimport library yang dibutuhkan

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np
from sklearn.cluster import KMeans

# %% [markdown]
# ## Mengambil dataset iris dari sklearn

# %%
# Get iris dataset
from sklearn.datasets import load_iris
iris = load_iris()
X = iris.data

# %% [markdown]
# ## Feature 1 dan 2

# %% [markdown]
# ### Clustering dataset iris dengan feature 1 dan 2

# %%
# Get feature 1 and 2
X1 = X[:,0]
X2 = X[:,1]
X12 = np.array(list(zip(X1, X2)))

# %%
# Plot the data
plt.scatter(X1, X2)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.show()

# %% [markdown]
# ### Menentukan Jumlah K dengan elbow method

# %%
# Elbow method
distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(X12)
    distortions.append(kmeanModel.inertia_)

# %%
# Plot the elbow
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('Optimal k for sepal length and width')
plt.show()

# %% [markdown]
# ### Clustering KMeans

# %%
# Cluster the data
kmeans = KMeans(n_clusters=3)
kmeans.fit(X12)
y_kmeans = kmeans.predict(X12)

# %% [markdown]
# ### Evaluasi

# %%
# Evaluate the clustering
from sklearn import metrics
print("Homogeneity: %0.3f" % metrics.homogeneity_score(iris.target, y_kmeans))
print("Completeness: %0.3f" % metrics.completeness_score(iris.target, y_kmeans))
print("V-measure: %0.3f" % metrics.v_measure_score(iris.target, y_kmeans))
print("Adjusted Rand Index: %0.3f"
        % metrics.adjusted_rand_score(iris.target, y_kmeans))
print("Adjusted Mutual Information: %0.3f"
        % metrics.adjusted_mutual_info_score(iris.target, y_kmeans))
print("Silhouette Coefficient: %0.3f"
        % metrics.silhouette_score(X12, y_kmeans))
# Out:
# Homogeneity: 0.646
# Completeness: 0.647
# V-measure: 0.647
# Adjusted Rand Index: 0.601
# Adjusted Mutual Information: 0.642
# Silhouette Coefficient: 0.445

# %% [markdown]
# ### Visualisasi

# %%
# Plot the clusters
plt.scatter(X1, X2, c=y_kmeans, s=50, cmap='plasma')
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.show()

# %% [markdown]
# ## Feature 2 and 3

# %% [markdown]
# ### Clustering dataset iris dengan feature 1 dan 2

# %%
# Feature 2 and 3
X2 = X[:,1]
X3 = X[:,2]

X23 = np.array(list(zip(X2, X3)))

# %%
# Plot the data
plt.scatter(X2, X3)
plt.xlabel('Sepal width')
plt.ylabel('Petal length')
plt.show()

# %% [markdown]
# ### Menentukan jumlah K dengan elbow method

# %%
# Elbow method
distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(X23)
    distortions.append(kmeanModel.inertia_)

# %%
# Plot the elbow
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('Optimal k for sepal width and petal length')
plt.show()

# %% [markdown]
# ### Clustering KMeans

# %%
# Cluster the data
kmeans = KMeans(n_clusters=2)
kmeans.fit(X23)
y_kmeans = kmeans.predict(X23)

# %% [markdown]
# ### Evaluasi

# %%
# Evaluate the clustering
from sklearn import metrics
print("Homogeneity: %0.3f" % metrics.homogeneity_score(iris.target, y_kmeans))
print("Completeness: %0.3f" % metrics.completeness_score(iris.target, y_kmeans))
print("V-measure: %0.3f" % metrics.v_measure_score(iris.target, y_kmeans))
print("Adjusted Rand Index: %0.3f"
        % metrics.adjusted_rand_score(iris.target, y_kmeans))
print("Adjusted Mutual Information: %0.3f"
        % metrics.adjusted_mutual_info_score(iris.target, y_kmeans))
print("Silhouette Coefficient: %0.3f"
        % metrics.silhouette_score(X23, y_kmeans))
# Out:
# Homogeneity: 0.554
# Completeness: 0.949
# V-measure: 0.699
# Adjusted Rand Index: 0.558
# Adjusted Mutual Information: 0.697
# Silhouette Coefficient: 0.739

# %% [markdown]
# ### Visualisasi

# %%
# Plot the clusters
plt.scatter(X2, X3, c=y_kmeans, s=50, cmap='viridis')
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)
plt.xlabel('Sepal width')
plt.ylabel('Petal length')
plt.show()

# %% [markdown]
# ## Perbedaan bx- x- dan x plot

# %% [markdown]
# ### Tampilan bx- plot

# %%
# Tampilan bx- plot
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('Optimal k for sepal width and petal length')
plt.show()

# %% [markdown]
# bx- plot memiliki arti sebagai berikut
#
# b: warna biru
#
# x: tanda x di tiap-tiap titik
#
# -: garis lurus
#
# Sehingga menghasilkan grafik seperti di atas.

# %% [markdown]
# ### Tampilan x- plot

# %%
# Tampilan x- plot
plt.plot(K, distortions, 'x-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('Optimal k for sepal width and petal length')
plt.show()

# %% [markdown]
# x- plot memiliki arti sebagai berikut
#
# x: tanda x di tiap-tiap titik
#
# -: garis lurus
#
# Meskipun tidak didefinisikan warna, grafik di atas tetap berwarna biru karena default dari warnanya adalah biru.

# %% [markdown]
# ### Tampilan x plot

# %%
# Tampilan x plot
plt.plot(K, distortions, 'x')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('Optimal k for sepal width and petal length')
plt.show()

# %% [markdown]
# x plot memiliki arti sebagai berikut
#
# x: tanda x di tiap-tiap titik
#
# Tidak didefinisikan warna dan garis lurus dengan dash (-), sehingga grafik di atas tidak memiliki garis lurus dan berwarna biru karena default dari warnanya adalah biru.
